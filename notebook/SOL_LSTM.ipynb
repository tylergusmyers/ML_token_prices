# %% [markdown]
# <a href="https://colab.research.google.com/github/tylergusmyers/ML_token_prices/blob/master_som/notebook/SOL_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Required libraries**

# %%
# Install the required libraries
from IPython.display import clear_output
try:
  #!pip install pystan
  # !pip install pytrends
  # !pip install yfinance
  # !pip install yahoofinancials
except:
  print("Error installing libraries")
finally:
  clear_output()
  print('Libraries successfully installed')
# Out:
# Libraries successfully installed

# %%
# Imports
import pandas as pd
import numpy as np
import tensorflow as tf
#from tensorflow.keras.layers import Dense
#from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM
from sklearn.metrics import mean_absolute_error
#from sklearn.preprocessing import StandardScaler,OneHotEncoder
from pathlib import Path
import yfinance as yf
import matplotlib.pyplot as plt


#import yfinance as yf
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from pytrends.request import TrendReq

# %% [markdown]
# **Build Bitcoin Historicall Data into Pandas DataFrame**

# %%
# Upload BitCoin historical data from Yahoo finance and load into Pandas DataFrame 
btc = yf.Ticker("SOL-USD")

# get historical market data
btc_usd_df = btc.history(
                          start='2017-01-01', 
                      end='2022-01-12', 
                      progress=False,
)


btc_usd_df
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2020-04-10    0.832005    1.313487  ...          0             0
# 2020-04-11    0.951054    1.049073  ...          0             0
# 2020-04-12    0.785448    0.956670  ...          0             0
# 2020-04-13    0.890760    0.891603  ...          0             0
# 2020-04-14    0.777832    0.796472  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2022-01-08  136.400162  147.837311  ...          0             0
# 2022-01-09  142.543121  145.440414  ...          0             0
# 2022-01-10  140.833633  143.563370  ...          0             0
# 2022-01-11  135.940903  143.299042  ...          0             0
# 2022-01-12  140.203751  152.936478  ...          0             0
#
# [643 rows x 7 columns]

# %%
# Drop columns "Dividens" and "Stocks Splits" as they are not relevant to crypto coins
btc_usd_df = btc_usd_df.drop(["Dividends", "Stock Splits"], axis=1)

btc_usd_df
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2020-04-10    0.832005    1.313487    0.694187    0.951054    87364276
# 2020-04-11    0.951054    1.049073    0.765020    0.776819    43862444
# 2020-04-12    0.785448    0.956670    0.762426    0.882507    38736897
# 2020-04-13    0.890760    0.891603    0.773976    0.777832    18211285
# 2020-04-14    0.777832    0.796472    0.628169    0.661925    16747614
# ...                ...         ...         ...         ...         ...
# 2022-01-08  136.400162  147.837311  134.021011  142.513458  2730000333
# 2022-01-09  142.543121  145.440414  138.394104  140.839005  1599123912
# 2022-01-10  140.833633  143.563370  130.796997  135.954941  2040883379
# 2022-01-11  135.940903  143.299042  134.133972  140.183853  1554197314
# 2022-01-12  140.203751  152.936478  138.546265  151.703110  2242337550
#
# [643 rows x 5 columns]

# %% [markdown]
# **Build Bitcoin Google Trend data into a DataFrame**

# %%
#Pull BitCoin global search trend Data from Google and load into a DataFrame

#pytrends = TrendReq(hl=’en-US’, tz=360)
pytrends = TrendReq()

#pytrends.build_payload(kw_list=['bitcoin', 'crypto', 'cryptocurrency', 'btc', 'BlockChain'], timeframe='2017-01-01 2022-01-12')

pytrends.build_payload(kw_list=['bitcoin'], timeframe='2017-01-01 2022-01-12')

# Interest

df = pytrends.interest_over_time().rename_axis('Date')


#df['isPartial'] = np.where((df.isPartial == 'False'), 0, df.isPartial)
#df['isPartial'] = np.where((df.isPartial == 'True'), 1, df.isPartial)

df = df.drop(["isPartial"], axis=1) #* 1000
df
# Out:
#             bitcoin
# Date
# 2017-01-01        8
# 2017-01-08        6
# 2017-01-15        5
# 2017-01-22        4
# 2017-01-29        5
# ...             ...
# 2021-12-12       27
# 2021-12-19       25
# 2021-12-26       24
# 2022-01-02       28
# 2022-01-09       28
#
# [263 rows x 1 columns]

# %% [markdown]
# **Build a Pandas DataFrame of US Federal Holidays for the same time period**

# %%
dates_df = pd.DataFrame(
    {'Date':pd.date_range('2017-01-01', '2022-01-12')}
)


dates_df['holiday'] = dates_df['Date']

dates_df = dates_df.set_index('Date')
dates_df
# Out:
#               holiday
# Date
# 2017-01-01 2017-01-01
# 2017-01-02 2017-01-02
# 2017-01-03 2017-01-03
# 2017-01-04 2017-01-04
# 2017-01-05 2017-01-05
# ...               ...
# 2022-01-08 2022-01-08
# 2022-01-09 2022-01-09
# 2022-01-10 2022-01-10
# 2022-01-11 2022-01-11
# 2022-01-12 2022-01-12
#
# [1838 rows x 1 columns]

# %%
cal = calendar()

holidays = cal.holidays(
    start=dates_df['holiday'].min(),
    end=dates_df['holiday'].max()
)

holidays
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-16', '2017-02-20', '2017-05-29',
#                '2017-07-04', '2017-09-04', '2017-10-09', '2017-11-10',
#                '2017-11-23', '2017-12-25', '2018-01-01', '2018-01-15',
#                '2018-02-19', '2018-05-28', '2018-07-04', '2018-09-03',
#                '2018-10-08', '2018-11-12', '2018-11-22', '2018-12-25',
#                '2019-01-01', '2019-01-21', '2019-02-18', '2019-05-27',
#                '2019-07-04', '2019-09-02', '2019-10-14', '2019-11-11',
#                '2019-11-28', '2019-12-25', '2020-01-01', '2020-01-20',
#                '2020-02-17', '2020-05-25', '2020-07-03', '2020-09-07',
#                '2020-10-12', '2020-11-11', '2020-11-26', '2020-12-25',
#                '2021-01-01', '2021-01-18', '2021-02-15', '2021-05-31',
#                '2021-07-05', '2021-09-06', '2021-10-11', '2021-11-11',
#                '2021-11-25', '2021-12-24', '2021-12-31'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates_df['holiday'] = dates_df['holiday'].isin(holidays).astype(int) 
dates_df = dates_df #* 1000

dates_df
# Out:
#             holiday
# Date
# 2017-01-01        0
# 2017-01-02        1
# 2017-01-03        0
# 2017-01-04        0
# 2017-01-05        0
# ...             ...
# 2022-01-08        0
# 2022-01-09        0
# 2022-01-10        0
# 2022-01-11        0
# 2022-01-12        0
#
# [1838 rows x 1 columns]

# %%
#btc_usd_df_01 = pd.concat ([btc_usd_df , dates_df, df], axis=1).fillna(0)
#btc_usd_df_01 = pd.concat ([btc_usd_df, df ], axis=1) #.fillna(0)
btc_usd_df_01 = pd.concat ([btc_usd_df ], axis=1)

target_col = 'Close'


btc_usd_df_01 = btc_usd_df_01.dropna()
btc_usd_df_01
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2020-04-10    0.832005    1.313487    0.694187    0.951054    87364276
# 2020-04-11    0.951054    1.049073    0.765020    0.776819    43862444
# 2020-04-12    0.785448    0.956670    0.762426    0.882507    38736897
# 2020-04-13    0.890760    0.891603    0.773976    0.777832    18211285
# 2020-04-14    0.777832    0.796472    0.628169    0.661925    16747614
# ...                ...         ...         ...         ...         ...
# 2022-01-08  136.400162  147.837311  134.021011  142.513458  2730000333
# 2022-01-09  142.543121  145.440414  138.394104  140.839005  1599123912
# 2022-01-10  140.833633  143.563370  130.796997  135.954941  2040883379
# 2022-01-11  135.940903  143.299042  134.133972  140.183853  1554197314
# 2022-01-12  140.203751  152.936478  138.546265  151.703110  2242337550
#
# [643 rows x 5 columns]

# %% [markdown]
# **Split features and target sets into Trainng and test datasets**

# %%
# Function to split the preprocessed data into a training  80% and testing  20% dataset

def train_test_split(df, test_size=0.2):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

train, test = train_test_split(btc_usd_df, test_size=0.2)

# %%
# Function to plot the test dataset and trainig dataset into a line

def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price (USD)', fontsize=14)
    ax.set_xlabel('year', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

# Display the line chart of the line plot for both the trainig and the test data set    
    
line_plot(train[target_col], test[target_col], 'Training Solana Close', 'Test Solana Close', title='Training and Test Data plot for Solana Close')

# %%
# Function to Normalize the dataFrame data

def normalise_df(df):
  return df / df.iloc[0] - 1

def normalise_df_min_max(df):
  return (df - df.min()) / (data.max() - df.min())

# %%
def extract_period_data(df, period_len, zero_base=True):
  period_data = []
  for x in range(len(df) - period_len):
    tmp = df[x: (x + period_len)].copy()                

    if zero_base:
      tmp = normalise_df(tmp)
    period_data.append(tmp.values)
  return np.array(period_data)

# %%
def prepare_data(df, target_col, period_len, zero_base, test_size):
  train_data, test_data = train_test_split(df, test_size=test_size)
  X_train = extract_period_data(train_data, period_len, zero_base)
  X_test = extract_period_data(test_data, period_len, zero_base)
  y_train = train_data[target_col][period_len:].values
  y_test = test_data[target_col][period_len:].values
  if zero_base:
    y_train = y_train / train_data[target_col][:-period_len].values - 1
    y_test = y_test / test_data[target_col][:-period_len].values - 1
  
  return train_data, test_data, X_train, X_test, y_train, y_test

# %%
def build_lstm_model(input_data, output_size, neurons, activ_func, dropout, loss, optimizer):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(input_data.shape[1], input_data.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))
    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
# Input parameters

period_len = 30
test_size = 0.2
zero_base = True
lstm_neurons = 100
epochs = 50
batch_size = 32
loss = 'mse'
dropout = 0.2
optimizer = 'adam'
activ_func = 'linear'
output_size = 1

# %%
# Call the function prepare_data to compute the training and testing dataset

train, test, X_train, X_test, y_train, y_test = prepare_data(btc_usd_df_01, target_col, period_len=period_len, zero_base=zero_base, test_size=test_size)

#X_train

# %%
#Call the function build_lstm_model  to initialize and build the neural net model using the input parameter define above

model = build_lstm_model(X_train, output_size, lstm_neurons, activ_func=activ_func, dropout=dropout, loss=loss, optimizer=optimizer)
history = model.fit(
    X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 3s 25ms/step - loss: 0.2377
# Epoch 2/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0913
# Epoch 3/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0694
# Epoch 4/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0681
# Epoch 5/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0603
# Epoch 6/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0559
# Epoch 7/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0578
# Epoch 8/50
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0490
# Epoch 9/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0486
# Epoch 10/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0521
# Epoch 11/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0511
# Epoch 12/50
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0512
# Epoch 13/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0493
# Epoch 14/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0457
# Epoch 15/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0510
# Epoch 16/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0462
# Epoch 17/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0468
# Epoch 18/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0450
# Epoch 19/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0412
# Epoch 20/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0516
# Epoch 21/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0430
# Epoch 22/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0438
# Epoch 23/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0410
# Epoch 24/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0408
# Epoch 25/50
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0417
# Epoch 26/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0434
# Epoch 27/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0456
# Epoch 28/50
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0384
# Epoch 29/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0415
# Epoch 30/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0401
# Epoch 31/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0367
# Epoch 32/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0406
# Epoch 33/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0371
# Epoch 34/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0352
# Epoch 35/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0354
# Epoch 36/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0349
# Epoch 37/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0337
# Epoch 38/50
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0377
# Epoch 39/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0350
# Epoch 40/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0398
# Epoch 41/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0426
# Epoch 42/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0359
# Epoch 43/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0339
# Epoch 44/50
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0355
# Epoch 45/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0382
# Epoch 46/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0382
# Epoch 47/50
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0347
# Epoch 48/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0368
# Epoch 49/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0383
# Epoch 50/50
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0346

# %%
# Define the target and period to for use in the prediction
targets = test[target_col][period_len:]
preds = model.predict(X_test).squeeze()
preds
# Out:
# array([-0.03311211, -0.14176345, -0.14583756, -0.11784773, -0.14456007,
#        -0.14511235, -0.0993487 , -0.04217809, -0.05756612,  0.03540365,
#         0.08861144, -0.05308967,  0.03974853,  0.20624629,  0.34344712,
#         0.26057854,  0.38090187,  0.46526343,  0.4492655 ,  0.5487316 ,
#         0.49130377,  0.5193057 ,  0.44259956,  0.39125785,  0.21301168,
#         0.17572667,  0.19231436,  0.292678  ,  0.4667308 ,  0.6371529 ,
#         0.60002786,  0.587929  ,  0.5848559 ,  0.6844516 ,  0.7050851 ,
#         0.6308075 ,  0.62557715,  0.57023335,  0.46920037,  0.47398448,
#         0.4981329 ,  0.52323246,  0.482109  ,  0.23530269,  0.10720792,
#         0.06442662,  0.09722127,  0.10386803,  0.05019924,  0.08685109,
#         0.16626592,  0.05779086, -0.02188293, -0.00499311, -0.01341684,
#         0.01240441, -0.00472119, -0.05209192, -0.06380485, -0.04979947,
#        -0.19314176, -0.19430837, -0.21306829, -0.20089346, -0.19454381,
#        -0.22999798, -0.23157905, -0.28377646, -0.2767859 , -0.30658296,
#        -0.22475807, -0.19405034, -0.10276908, -0.18023154, -0.18369396,
#        -0.22925033, -0.17338842, -0.18868522, -0.1354168 , -0.08474499,
#         0.0017789 ,  0.00236844, -0.00602908, -0.04774585, -0.11476975,
#        -0.22778405, -0.25510767, -0.18436308, -0.11653496, -0.1108406 ,
#        -0.10200996, -0.12616985, -0.16911748, -0.15085083, -0.12619013,
#        -0.1772471 , -0.20026268, -0.12033523], dtype=float32)

# %%
# Review the mean_absoluter_error for the prediction with the test data

#targets = test[target_col][period_len:]

mean_absolute_error(preds, y_test)
# Out:
# 0.05621253373240551

# %%
# Compare and visualize the prediction and the actual data
preds = test[target_col].values[:-period_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'actual', 'prediction', lw=3)
